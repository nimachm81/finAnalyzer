# %%
import urllib

htmlfile = urllib.request.urlopen('https://www.sec.gov/cgi-bin/viewer?action=view&cik=913760&accession_number=0000913760-19-000110&xbrl_type=v')
htmltext = htmlfile.read().decode('utf-8')

print(htmltext)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <title>View Filing Data</title>
# <script type="text/javascript" src="/include/jquery-1.4.3.min.js"></script>
# <script type="text/javascript" src="/include/accordionMenu.js"></script>
# <script type="text/javascript" src="/include/Show.js"></script>
# <link rel="stylesheet" type="text/css" href="/include/interactive.css" />
# <link rel="stylesheet" type="text/css" href="/include/report.css" />
# <link rel="stylesheet" type="text/css" href="/include/print.css" media="print" />
# <link rel="stylesheet" type="text/css" href="/include/xbrlViewerStyle.css" />
# <style type="text/css">li.octave {border-top: 1px solid black;}</style>
# <!--[if lt IE 8]>
# <style type="text/css">
# li.accordion a {display:inline-block;}
# li.accordion a {display:block;}
# </style>
# <![endif]-->
# <script type="text/javascript" language="javascript">
# var InstanceReportXslt = "/include/InstanceReport.xslt";
# var reports = new Array(83);
#     reports[0+1] = "/Archives/edgar/data/913760/000091376019000110/R1.htm";
#     reports[1+1] = "/Archives/edgar/data/913760/000091376019000110/R2.htm";
#     reports[2+1] = "/Archives/edgar/data/913760/000091376019000110/R3.htm";
#     reports[3+1] = "/Archives/edgar/data/913760/000091376019000110/R4.htm";
#     reports[4+1] = "/Archives/edgar/data/913760/000091376019000110/R5.htm";
#     reports[5+1] = "/Archives/edgar/data/913760/000091376019000110/R6.htm";
#     reports[6+1] = "/Archives/edgar/data/913760/000091376019000110/R7.htm";
#     reports[7+1] = "/Archives/edgar/data/913760/000091376019000110/R8.htm";
#     reports[8+1] = "/Archives/edgar/data/913760/000091376019000110/R9.htm";
#     reports[9+1] = "/Archives/edgar/data/913760/000091376019000110/R10.htm";
#     reports[10+1] = "/Archives/edgar/data/913760/000091376019000110/R11.htm";
#     reports[11+1] = "/Archives/edgar/data/913760/000091376019000110/R12.htm";
#     reports[12+1] = "/Archives/edgar/data/913760/000091376019000110/R13.htm";
#     reports[13+1] = "/Archives/edgar/data/913760/000091376019000110/R14.htm";
#     reports[14+1] = "/Archives/edgar/data/913760/000091376019000110/R15.htm";
#     reports[15+1] = "/Archives/edgar/data/913760/000091376019000110/R16.htm";
#     reports[16+1] = "/Archives/edgar/data/913760/000091376019000110/R17.htm";
#     reports[17+1] = "/Archives/edgar/data/913760/000091376019000110/R18.htm";
#     reports[18+1] = "/Archives/edgar/data/913760/000091376019000110/R19.htm";
#     reports[19+1] = "/Archives/edgar/data/913760/000091376019000110/R20.htm";
#     reports[20+1] = "/Archives/edgar/data/913760/000091376019000110/R21.htm";
#     reports[21+1] = "/Archives/edgar/data/913760/000091376019000110/R22.htm";
#     reports[22+1] = "/Archives/edgar/data/913760/000091376019000110/R23.htm";
#     reports[23+1] = "/Archives/edgar/data/913760/000091376019000110/R24.htm";
#     reports[24+1] = "/Archives/edgar/data/913760/000091376019000110/R25.htm";
#     reports[25+1] = "/Archives/edgar/data/913760/000091376019000110/R26.htm";
#     reports[26+1] = "/Archives/edgar/data/913760/000091376019000110/R27.htm";
#     reports[27+1] = "/Archives/edgar/data/913760/000091376019000110/R28.htm";
#     reports[28+1] = "/Archives/edgar/data/913760/000091376019000110/R29.htm";
#     reports[29+1] = "/Archives/edgar/data/913760/000091376019000110/R30.htm";
#     reports[30+1] = "/Archives/edgar/data/913760/000091376019000110/R31.htm";
#     reports[31+1] = "/Archives/edgar/data/913760/000091376019000110/R32.htm";
#     reports[32+1] = "/Archives/edgar/data/913760/000091376019000110/R33.htm";
#     reports[33+1] = "/Archives/edgar/data/913760/000091376019000110/R34.htm";
#     reports[34+1] = "/Archives/edgar/data/913760/000091376019000110/R35.htm";
#     reports[35+1] = "/Archives/edgar/data/913760/000091376019000110/R36.htm";
#     reports[36+1] = "/Archives/edgar/data/913760/000091376019000110/R37.htm";
#     reports[37+1] = "/Archives/edgar/data/913760/000091376019000110/R38.htm";
#     reports[38+1] = "/Archives/edgar/data/913760/000091376019000110/R39.htm";
#     reports[39+1] = "/Archives/edgar/data/913760/000091376019000110/R40.htm";
#     reports[40+1] = "/Archives/edgar/data/913760/000091376019000110/R41.htm";
#     reports[41+1] = "/Archives/edgar/data/913760/000091376019000110/R42.htm";
#     reports[42+1] = "/Archives/edgar/data/913760/000091376019000110/R43.htm";
#     reports[43+1] = "/Archives/edgar/data/913760/000091376019000110/R44.htm";
#     reports[44+1] = "/Archives/edgar/data/913760/000091376019000110/R45.htm";
#     reports[45+1] = "/Archives/edgar/data/913760/000091376019000110/R46.htm";
#     reports[46+1] = "/Archives/edgar/data/913760/000091376019000110/R47.htm";
#     reports[47+1] = "/Archives/edgar/data/913760/000091376019000110/R48.htm";
#     reports[48+1] = "/Archives/edgar/data/913760/000091376019000110/R49.htm";
#     reports[49+1] = "/Archives/edgar/data/913760/000091376019000110/R50.htm";
#     reports[50+1] = "/Archives/edgar/data/913760/000091376019000110/R51.htm";
#     reports[51+1] = "/Archives/edgar/data/913760/000091376019000110/R52.htm";
#     reports[52+1] = "/Archives/edgar/data/913760/000091376019000110/R53.htm";
#     reports[53+1] = "/Archives/edgar/data/913760/000091376019000110/R54.htm";
#     reports[54+1] = "/Archives/edgar/data/913760/000091376019000110/R55.htm";
#     reports[55+1] = "/Archives/edgar/data/913760/000091376019000110/R56.htm";
#     reports[56+1] = "/Archives/edgar/data/913760/000091376019000110/R57.htm";
#     reports[57+1] = "/Archives/edgar/data/913760/000091376019000110/R58.htm";
#     reports[58+1] = "/Archives/edgar/data/913760/000091376019000110/R59.htm";
#     reports[59+1] = "/Archives/edgar/data/913760/000091376019000110/R60.htm";
#     reports[60+1] = "/Archives/edgar/data/913760/000091376019000110/R61.htm";
#     reports[61+1] = "/Archives/edgar/data/913760/000091376019000110/R62.htm";
#     reports[62+1] = "/Archives/edgar/data/913760/000091376019000110/R63.htm";
#     reports[63+1] = "/Archives/edgar/data/913760/000091376019000110/R64.htm";
#     reports[64+1] = "/Archives/edgar/data/913760/000091376019000110/R65.htm";
#     reports[65+1] = "/Archives/edgar/data/913760/000091376019000110/R66.htm";
#     reports[66+1] = "/Archives/edgar/data/913760/000091376019000110/R67.htm";
#     reports[67+1] = "/Archives/edgar/data/913760/000091376019000110/R68.htm";
#     reports[68+1] = "/Archives/edgar/data/913760/000091376019000110/R69.htm";
#     reports[69+1] = "/Archives/edgar/data/913760/000091376019000110/R70.htm";
#     reports[70+1] = "/Archives/edgar/data/913760/000091376019000110/R71.htm";
#     reports[71+1] = "/Archives/edgar/data/913760/000091376019000110/R72.htm";
#     reports[72+1] = "/Archives/edgar/data/913760/000091376019000110/R73.htm";
#     reports[73+1] = "/Archives/edgar/data/913760/000091376019000110/R74.htm";
#     reports[74+1] = "/Archives/edgar/data/913760/000091376019000110/R75.htm";
#     reports[75+1] = "/Archives/edgar/data/913760/000091376019000110/R76.htm";
#     reports[76+1] = "/Archives/edgar/data/913760/000091376019000110/R77.htm";
#     reports[77+1] = "/Archives/edgar/data/913760/000091376019000110/R78.htm";
#     reports[78+1] = "/Archives/edgar/data/913760/000091376019000110/R79.htm";
#     reports[79+1] = "/Archives/edgar/data/913760/000091376019000110/R80.htm";
#     reports[80+1] = "/Archives/edgar/data/913760/000091376019000110/R81.htm";
#     reports[81+1] = "/Archives/edgar/data/913760/000091376019000110/R82.htm";
#     reports[82+1] = 'all';
#
#    function loadXSLDoc(url) {
#       var doc;
#       var jqxhr=$.ajax({type: "GET",
#                         url: url,
#                         async: false});
#
#       // code for IE
#       if (window.ActiveXObject || "ActiveXObject" in window) {
#          doc = new ActiveXObject("Msxml2.FreeThreadedDOMDocument.3.0");
#          doc.loadXML(jqxhr.responseText);
#       }
#
#       // code for other browsers
#       else if (document.implementation && document.implementation.createDocument) {
#          doc=document.implementation.createDocument("","",null);
#          doc.async=true;
#          doc = jqxhr.responseXML.documentElement;
#       }
#
#       return doc;
#    }
#
#    function fixSrcAttr(src) {
#       var url_path = "/Archives/edgar/data/913760/000091376019000110/";
#       var uri = src.substr(0,5);
#       // No change is needed if the 'src' attribute contains an embedded image
#       if (uri == 'data:') {
#          return src;
#       }
#       // Absolute URL on EDGAR website is unchanged
#       var idx = src.lastIndexOf('https://s3.amazonaws.com/archives.sec.gov/edgar/data/')
#       if (idx > -1) {
#         return src;
#       } // For all other URLs use only basename component
#       var idx = src.lastIndexOf('/');
#       if (idx > -1) {
#          src = src.substring(idx+1,src.length);
#       }
#       return url_path + src;
#    }
#
#    function getReport(url, xsl_url) {
#       if (xsl_url == null) { xsl_url = InstanceReportXslt; }
#       var ext = url.substring(url.lastIndexOf('.')+1, url.length);
#       if (ext == 'htm') {
#           $.ajax({
#           type: "GET",
#           url: url,
#           dataType: "text",
#           async:false,
#           success: function (data) {
#                   // Strip out everything between the "TEXT" elements
#                   var idx = data.indexOf('<TEXT>');
#                   if (idx > -1) {
#                      data = data.substring(idx+6,data.length);
#                      idx = data.indexOf('</TEXT>');
#                      if ( idx > -1) {
#                         data = data.substring(0,idx);
#                      }
#                   }
#           	 jQuery('#reportDiv').append(data)
#                   .find('img').attr('src', function(i, val) { return fixSrcAttr(val);}).end();
#               }
#           });
#       } else {
#           $.ajax({
#           type: "GET",
#           url: url,
#           dataType: "text",
#           async: false,
#           success: function(data) {
#                   data = data.replace(/^\s+|\s+$/g, ''); // leading or trailing whitespace causes problems
#                   var path="/" + url.substring(1, url.lastIndexOf('/')+1);
#
#                   // code for IE
#                   if (window.ActiveXObject || "ActiveXObject" in window) {
#                      xsl_doc = loadXSLDoc(xsl_url)
#                      var xslt = new ActiveXObject("Msxml2.XSLTemplate.3.0");
#                      xslt.stylesheet = xsl_doc;
#                      var xslproc = xslt.createProcessor();
#                      var doc = new ActiveXObject("Msxml2.FreeThreadedDOMDocument.3.0");
#                      doc.loadXML(data);
#                      xslproc.input = doc;
#                      xslproc.addParameter("source", path );
#                      xslproc.addParameter("asPage", "true" );
#                      xslproc.transform();
#                      // Find all images and prepend the base URL to the src attribute
#                      jQuery('#reportDiv').append(jQuery(xslproc.output)
#                                          .find('img')
#                                          .attr('src', function(i, val) {
#                                                          return fixSrcAttr(val);
#                                                       }).end());
#                   }
#                   // code for other browsers
#                   else if (document.implementation && document.implementation.createDocument) {
#                      xsltProcessor=new XSLTProcessor();
#                      xsltProcessor.importStylesheet(loadXSLDoc(xsl_url));
#                      xsltProcessor.setParameter(null,"source",path);
#                      xsltProcessor.setParameter(null,"asPage","true");
#                      parser = new DOMParser();
#                      xmlDoc = parser.parseFromString(data, "text/xml");
#                      var rpt = xsltProcessor.transformToFragment(xmlDoc, document);
#                      document.getElementById("reportDiv").appendChild(rpt);
#                      FixNotesForGeckoWebkit( document.getElementById( 'reportDiv' ) );
#                      // Find all images and prepend the base URL to the src attribute
#                      jQuery('#reportDiv').find('img')
#                                          .attr('src', function(i, val) {
#                                                          return fixSrcAttr(val);
#                                                       });
#                   } else {
#                      alert('Your browser cannot handle this script');
#                   }
#                }
#             });
#        }
#    }
#
#    function clearReportDiv() {
#       // code for IE
#       if (window.ActiveXObject || "ActiveXObject" in window) {
#          document.getElementById("reportDiv").innerHTML='';
#       }
#
#       // code for Mozilla, Firefox, Opera, etc.
#       else if (document.implementation && document.implementation.createDocument) {
#          x = document.getElementById("reportDiv").childNodes;
#          for (i=x.length-1;i>-1;i--) {
#             node = document.getElementById("reportDiv").childNodes[i];
#             if (node) {
#                document.getElementById("reportDiv").removeChild(node);
#             }
#          }
#       }
#    }
#
#    function loadReport(idx) {
#       if (window.XMLHttpRequest || window.ActiveXObject || "ActiveXObject" in window) {
#          clearReportDiv();
#          xsl_url = null;
#          if (reports[idx] == 'all') {
#             highlightAllMenuItems();
#             jQuery.ajaxSetup({async:false});
#             for (var i=1; i<=reports.length; i++) {
#                if (reports[i] != 'all') {
#                   getReport(reports[i], xsl_url);
#                   var li = document.getElementById('r'+idx);
#                   if (li) {
#                      li.parentNode.style.display='block';
#                   }
#                } else {
#                   break;
#                }
#             }
#          }
#
#          else {
#             getReport(reports[idx], xsl_url);
#             var li = document.getElementById('r'+idx);
#             if (li) {
#                li.parentNode.style.display='block';
#             }
#          }
#          window.scrollTo(0,0);
#       }
#
#       else {
#          alert('Your browser cannot handle this script');
#       }
#    }
#
#    function highlight(link) {
#       var parent = document.getElementById( 'menu' );
#       var links = parent.getElementsByTagName( 'a' );
#
#       for (var i = 0; i < links.length; i++){
#          if (links[i].className == 'xbrlviewer') {
#             if (links[i] == link) {
#                link.style.background = "#C1CDCD";
#             } else {
#                links[i].style.background = "#F5F5EB";
#             }
#          }
#       }
#    }
#
#    //the parameter 'div' represents <div id="reportDiv">
#    function FixNotesForGeckoWebkit( div ){
#       //textContent is only found in "other" browsers
#       //if it exists, search it for our table - there should only be one
#       if( div.textContent ){
#          var tables = div.getElementsByTagName( 'table' );
#          if( tables.length ){
#             //loop through the tables
#            for( var t = 0; t < tables.length; t++ ){
#               var cells = tables[t].getElementsByTagName( 'td' );
#               //loop through the cells, checking for class="text" which indicates some kind of text content - this includes HTML for notes
#               for( var i = 0; i < cells.length; i++ ){
#                  var curCell = cells[ i ];
#                  if( curCell.className == 'text' ){
#                     //<td class="text" found - now check if this HTML had already been rendered - if so, we should not attempt to render it again
#                     var nodes = curCell.getElementsByTagName( '*' );
#                     if( nodes.length <= 1 ){
#                        //no "nodes" found so perform a secondary check that we have text which resembles HTML
#                        nodes = curCell.textContent.match( /<\/?[a-zA-Z]{1}\w*[^>]*>/g );
#                        if( nodes && nodes.length ){
#                           //this text does resemble HTML, use the textContent as HTML and that will convert the text to HTML content.
#                           curCell.innerHTML = curCell.textContent;
#                         }
#                      }
#                   }
#                }
#             }
#          }
#       }
#    }
#
#
#    window.onload = function () {
#       loadReport(1);
#    }
#
# </script>
# </head>
# <body style="margin: 0">
# <noscript><div style="color:red; font-weight:bold; text-align:center;">This page uses Javascript. Your browser either doesn't support Javascript or you have it turned off. To see this page as it is meant to appear please use a Javascript enabled browser.</div></noscript>
# <!-- BEGIN BANNER -->
# <div id="headerTop">
#    <div id="Nav"><a href="/index.htm">Home</a> | <a href="/cgi-bin/browse-edgar?action=getcurrent">Latest Filings</a> | <a href="javascript:history.back()">Previous Page</a></div>
#    <div id="seal"><a href="http://www.sec.gov/index.htm"><img src="/images/sealTop.gif" alt="SEC Seal" border="0" /></a></div>
#    <div id="secWordGraphic"><img src="/images/bannerTitle.gif" alt="SEC Banner" /></div>
# </div>
# <div id="headerBottom">
#    <div id="searchHome"><a href="/edgar/searchedgar/webusers.htm">Search the Next-Generation EDGAR System</a></div>
#    <div id="PageTitle">View Filing Data</div>
# </div>
# <!-- END BANNER -->
# <!-- BEGIN BREADCRUMBS -->
# <div id="breadCrumbs">
#    <ul>
#       <li><a href="/">SEC Home</a> &#187;</li>
#       <li><a href="/edgar/searchedgar/webusers.htm">Search the Next-Generation EDGAR System</a> &#187;</li>
#       <li><a href="/edgar/searchedgar/companysearch.html">Company Search</a> &#187;</li>
#       <li class="last">Current Page</li>
#    </ul>
# </div>
# <!-- END BREADCRUMBS -->
# <!-- START COMPANY HEADERS DIV -->
# <div style="margin: 5px 20px 0px 20px; padding-top: 5px; padding-left: 5px;">
#    <div class="companyInfo">
#      <span class="companyName">INTL FCSTONE INC. (Filer) <acronym title="Central Index Key">CIK</acronym>: 0000913760</span>
#    </div>
#    <div class="clear"></div>
# </div>
# <!-- END COMPANY HEADERS DIV -->
# <!-- START CONTENT DIV -->
# <div>
#    <table>
#      <tr>
#         <td colspan="2"><a class="xbrlviewer" style="color: black; font-weight: bold;" href="javascript:window.print();">Print Document</a>&nbsp;<a class="xbrlviewer" href="/Archives/edgar/data/913760/000091376019000110/Financial_Report.xlsx">View Excel Document</a></td>
#      </tr>
#      <tr>
#        <td style="vertical-align: top;">
#
# <div style="width: 170px; margin-right: 5px;">
#   <ul id="menu">
# <!-- cover_category = 0 -->    <li class="accordion">
#       <a id="menu_cat1" href="#">Cover</a>
#       <ul>
#             <li class="accordion" id="r1" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(1);">DEI</a></li>
#       </ul>
#     </li>
#     <li class="accordion">
#       <a id="menu_cat2" href="#">Financial Statements</a>
#       <ul>
#             <li class="accordion" id="r2" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(2);">Condensed Consolidated Balance Sheets</a></li>
#             <li class="accordion" id="r3" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(3);">Condensed Consolidated Balance Sheets Parentheticals</a></li>
#             <li class="accordion" id="r4" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(4);">Condensed Consolidated Income Statements</a></li>
#             <li class="accordion" id="r5" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(5);">Condensed Consolidated Statement of Comprehensive Income</a></li>
#             <li class="accordion" id="r6" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(6);">Condensed Consolidated Cash Flows Statements</a></li>
#             <li class="accordion" id="r7" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(7);">Condensed Consolidated Cash Flows Statements Reconciliation of Cash, Segregated Cash, Cash Equivalents, and Segregated Cash Equivalents</a></li>
#             <li class="accordion" id="r8" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(8);">Condensed Consolidated Statement of Stockholders' Equity</a></li>
#       </ul>
#     </li>
#     <li class="accordion">
#       <a id="menu_cat3" href="#">Notes to Financial Statements</a>
#       <ul>
#             <li class="accordion" id="r9" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(9);">Basis of Presentation and Consolidation and Recently Issued Accounting Standards (Notes)</a></li>
#             <li class="accordion" id="r10" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(10);">Revenue from Contracts with Clients (Notes)</a></li>
#             <li class="accordion" id="r11" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(11);">Earnings per Share (Notes)</a></li>
#             <li class="accordion" id="r12" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(12);">Assets and Liabilities, at Fair Value (Notes)</a></li>
#             <li class="accordion" id="r13" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(13);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk (Notes)</a></li>
#             <li class="accordion" id="r14" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(14);">Receivables From Customers, Net and Notes Receivable, Net (Notes)</a></li>
#             <li class="accordion" id="r15" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(15);">Physical Commodities Inventory (Notes)</a></li>
#             <li class="accordion" id="r16" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(16);">Goodwill (Notes)</a></li>
#             <li class="accordion" id="r17" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(17);">Intangible Assets - (Notes)</a></li>
#             <li class="accordion" id="r18" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(18);">Credit Facilities (Notes)</a></li>
#             <li class="accordion" id="r19" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(19);">Commodity and Other Repurchase Agreements and Collateralized Transactions (Notes)</a></li>
#             <li class="accordion" id="r20" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(20);">Commitments and Contingencies (Notes)</a></li>
#             <li class="accordion" id="r21" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(21);">Capital and Other Regulatory Requirements (Notes)</a></li>
#             <li class="accordion" id="r22" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(22);">Other Expenses (Notes)</a></li>
#             <li class="accordion" id="r23" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(23);">Accumulated Other Comprehensive Income (Loss) (Notes)</a></li>
#             <li class="accordion" id="r24" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(24);">Income Taxes (Notes)</a></li>
#             <li class="accordion" id="r25" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(25);">Acquisitions Acquisitions (Notes)</a></li>
#             <li class="accordion" id="r26" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(26);">Segment Analysis (Notes)</a></li>
#             <li class="accordion" id="r27" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(27);">Subsequent Events Subsequent Events (Notes)</a></li>
#       </ul>
#     </li>
#     <li class="accordion">
#       <a id="menu_cat4" href="#">Accounting Policies</a>
#       <ul>
#             <li class="accordion" id="r28" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(28);">Basis of Presentation and Consolidation and Recently Issued Accounting Standards (Policies)</a></li>
#             <li class="accordion" id="r29" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(29);">Earnings per Share (Policies)</a></li>
#             <li class="accordion" id="r30" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(30);">Income Taxes (Policies)</a></li>
#       </ul>
#     </li>
#     <li class="accordion">
#       <a id="menu_cat5" href="#">Notes Tables</a>
#       <ul>
#             <li class="accordion" id="r31" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(31);">Revenue from Contracts with Clients Disaggregation of Revenues Table (Tables)</a></li>
#             <li class="accordion" id="r32" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(32);">Earnings per Share (Tables)</a></li>
#             <li class="accordion" id="r33" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(33);">Assets and Liabilities, at Fair Value (Tables)</a></li>
#             <li class="accordion" id="r34" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(34);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk (Tables)</a></li>
#             <li class="accordion" id="r35" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(35);">Physical Commodities Inventory Physical Commodities Table (Tables)</a></li>
#             <li class="accordion" id="r36" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(36);">Goodwill (Tables)</a></li>
#             <li class="accordion" id="r37" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(37);">Intangible Assets - (Tables)</a></li>
#             <li class="accordion" id="r38" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(38);">Credit Facilities (Tables)</a></li>
#             <li class="accordion" id="r39" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(39);">Commodity and Other Repurchase Agreements and Collateralized Transactions Schedule of Gross Collateralized Financings by Maturity (Tables)</a></li>
#             <li class="accordion" id="r40" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(40);">Commodity and Other Repurchase Agreements and Collateralized Transactions Schedule of Collateralized Financings by Collateral Type (Tables)</a></li>
#             <li class="accordion" id="r41" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(41);">Capital and Other Regulatory Requirements (Tables)</a></li>
#             <li class="accordion" id="r42" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(42);">Other Expenses (Tables)</a></li>
#             <li class="accordion" id="r43" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(43);">Accumulated Other Comprehensive Income (Loss) (Tables)</a></li>
#             <li class="accordion" id="r44" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(44);">Acquisitions Purchase Price Allocation (Tables)</a></li>
#             <li class="accordion" id="r45" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(45);">Segment Analysis (Tables)</a></li>
#       </ul>
#     </li>
#     <li class="accordion">
#       <a id="menu_cat6" href="#">Notes Details</a>
#       <ul>
#             <li class="accordion" id="r46" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(46);">Basis of Presentation and Consolidation and Recently Issued Accounting Standards (Details)</a></li>
#             <li class="accordion" id="r47" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(47);">Revenue from Contracts with Clients Disaggregation of Revenues Table (Details)</a></li>
#             <li class="accordion" id="r48" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(48);">Earnings per Share - EPS Reconciliation (Details)</a></li>
#             <li class="accordion" id="r49" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(49);">Earnings per Share - Antidulitive Securities (Details)</a></li>
#             <li class="accordion" id="r50" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(50);">Assets and Liabilities, at Fair Value - Financial Assets and Liabilities Measured at Fair Value (Details)</a></li>
#             <li class="accordion" id="r51" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(51);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk - Obligations to Purchase Financial Instruments at a Future Date (Details)</a></li>
#             <li class="accordion" id="r52" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(52);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk  - Gross Derivative Assets and Liabilities by Type and Balance Sheet Location (Details)</a></li>
#             <li class="accordion" id="r53" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(53);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk  - Derivatives Volume (Details)</a></li>
#             <li class="accordion" id="r54" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(54);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk - TBAs and Forward Settling Securities (Details)</a></li>
#             <li class="accordion" id="r55" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(55);">Financial Instruments with Off-Balance Sheet Risk and Concentrations of Credit Risk - Realized Gains/Losses on Derivative Contracts (Details)</a></li>
#             <li class="accordion" id="r56" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(56);">Receivables From Customers, Net and Notes Receivable, Net - Allowance for Customer Receivables (Details)</a></li>
#             <li class="accordion" id="r57" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(57);">Receivables From Customers, Net and Notes Receivable, Net Receivables from Customers, Net and Notes Receivables, Net - Bad Debt Expense and Recoveries (Details)</a></li>
#             <li class="accordion" id="r58" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(58);">Physical Commodities Inventory - Physical Commodities Inventory by CIP and Finished (Details)</a></li>
#             <li class="accordion" id="r59" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(59);">Physical Commodities Inventory - LCM Adjustments (Details)</a></li>
#             <li class="accordion" id="r60" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(60);">Goodwill - Goodwill by Segment (Details)</a></li>
#             <li class="accordion" id="r61" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(61);">Goodwill Goodwill Adjustments (Details)</a></li>
#             <li class="accordion" id="r62" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(62);">Intangible Assets - Gross and Net Intangible Assets by Major Class (Details)</a></li>
#             <li class="accordion" id="r63" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(63);">Intangible Assets - Indefinite-Lived Intangible Assets (Details)</a></li>
#             <li class="accordion" id="r64" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(64);">Intangible Assets - Finite-Lived Intangible Assets Future Amortization Expense (Details)</a></li>
#             <li class="accordion" id="r65" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(65);">Intangible Assets Definite Lived Intangible Assets Amortization (Details)</a></li>
#             <li class="accordion" id="r66" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(66);">Intangible Assets Intangible Assets Acquired (Details)</a></li>
#             <li class="accordion" id="r67" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(67);">Credit Facilities - Number of Credit Facilities (Details)</a></li>
#             <li class="accordion" id="r68" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(68);">Credit Facilities - Credit Facilities (Details)</a></li>
#             <li class="accordion" id="r69" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(69);">Commodity and Other Repurchase Agreements Commodity and Other Repurchase Agreements (Details)</a></li>
#             <li class="accordion" id="r70" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(70);">Commodity and Other Repurchase Agreements and Collateralized Transactions Gross Financings Collateral Maturities Table (Details)</a></li>
#             <li class="accordion" id="r71" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(71);">Commodity and Other Repurchase Agreements and Collateralized Transactions Gross Collateralized Financings by Collateral Type Table (Details)</a></li>
#             <li class="accordion" id="r72" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(72);">Commitments and Contingencies Commitments and Contingencies - Contingencies and Litigation (Details)</a></li>
#             <li class="accordion" id="r73" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(73);">Commitments and Contingencies Commitments and Contingencies - Self Insurance (Details)</a></li>
#             <li class="accordion" id="r74" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(74);">Capital and Other Regulatory Requirements - Regulatory Capital Requirements (Details)</a></li>
#             <li class="accordion" id="r75" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(75);">Other Expenses - Other Expenses Breakout (Details)</a></li>
#             <li class="accordion" id="r76" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(76);">Accumulated Other Comprehensive Income (Loss) Rollforward (Details)</a></li>
#             <li class="accordion" id="r77" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(77);">Income Taxes (Details)</a></li>
#             <li class="accordion" id="r78" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(78);">Acquisitions Akshay Financeware, Inc. Acquisition (Details)</a></li>
#             <li class="accordion" id="r79" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(79);">Acquisitions GMP Securities Acquisition (Details)</a></li>
#             <li class="accordion" id="r80" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(80);">Acquisitions UOB Acquisition (Details)</a></li>
#             <li class="accordion" id="r81" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(81);">Acquisitions Coininvest and EPMT Acquisitions (Details)</a></li>
#             <li class="accordion" id="r82" ><a class="xbrlviewer" onClick="javascript:highlight(this);" href="javascript:loadReport(82);">Segment Analysis (Details)</a></li>
#       </ul>
#     </li>
#     <li><a href="javascript:loadReport(1+82);"><img src="/images/reports.gif" border="0" height="12" width="9" alt="Reports" />All Reports</a></li>
#   </ul>
# </div>
#
#        </td>
#        <td style="vertical-align: top;">
#          <div id="reportDiv"></div>
#        </td>
#      </tr>
#    </table>
# </div>
# <div style="clear:both"></div>
# <div id="help"></div>
# <!-- END CONTENT DIV -->
# <!-- START FILER DIV -->
# <div id="contentDiv">
#    <div id="filerDiv">
#       <div class="mailer">Mailing Address
#          <span class="mailerAddress">708 THIRD AVENUE</span>
#          <span class="mailerAddress">SUITE 1500</span>
#          <span class="mailerAddress">
# NEW YORK NY 10017         </span>
#       </div>
#       <div class="mailer">Business Address
#          <span class="mailerAddress">708 THIRD AVENUE</span>
#          <span class="mailerAddress">SUITE 1500</span>
#          <span class="mailerAddress">
# NEW YORK NY 10017         </span>
#          <span class="mailerAddress">212-485-3500</span>
#       </div>
#       <div class="companyInfo">
#           <span class="companyName">INTL FCSTONE INC. (Filer) <acronym title="Central Index Key">CIK</acronym>: <a href="/cgi-bin/browse-edgar?CIK=0000913760&amp;action=getcompany">0000913760 (see all company filings)</a></span> <p class="identInfo"><acronym title="Internal Revenue Service Number">IRS No.</acronym>: <strong>592921318</strong> | State of Incorp.: <strong>DE</strong> | Fiscal Year End: <strong>0930</strong><br />Type: <strong>10-Q</strong> | Act: <strong>34</strong> | File No.: <a href="/cgi-bin/browse-edgar?filenum=001-36045&amp;action=getcompany"><strong>001-36045</strong></a> | Film No.: <strong>191010881</strong><br /><acronym title="Standard Industrial Code">SIC</acronym>: <b><a href="/cgi-bin/browse-edgar?action=getcompany&amp;SIC=6200&amp;owner=include">6200</a></b> Security &amp; Commodity Brokers, Dealers, Exchanges &amp; Services<br />Assistant Director Office of Finance</p>
#       </div>
#       <div class="clear"></div>
#    </div>
# </div>
# <!-- END FILER DIV -->
# <!-- END FOOTER DIV -->
# <div id="footer">
#   <div class="currentURL">https://www.sec.gov/cgi-bin/viewer</div>
#   <div class="links"><a href="/index.htm">Home</a> | <a href="/edgar/searchedgar/webusers.htm">Search the Next-Generation EDGAR System</a> | <a href="javascript:history.back()">Previous Page</a></div>
#   <div class="modified">Modified 02/20/2019</div>
# </div>
# <!-- END FOOTER DIV -->
# </body>
# </html>

# %% [markdown]
# ### Read financial statements from SEC

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox()
driver.get("https://www.sec.gov/cgi-bin/viewer?action=view&cik=913760&accession_number=0000913760-19-000110&xbrl_type=v")
print(driver.title)
# Out:
# View Filing Data

# %%
fs_element = driver.find_element_by_partial_link_text("Financial Statements")
fs_element.click()

fs_siblings = fs_element.find_elements_by_xpath("../*")
assert len(fs_siblings) == 2

# %%
fs_list = fs_siblings[1].find_elements_by_xpath("*")


fs_list[0].click()


fs_data = fs_element.find_elements_by_xpath("../../../../../*")
print(len(fs_data))

fs_data[1].get_attribute('outerHTML')
# Out:
# 2
# '<td style="vertical-align: top;">\n         <div id="reportDiv"></div> \n       </td>'

# %% [markdown]
# ### Search SEC for company name

# %%
symbol = "aapl"
url = "https://www.sec.gov/cgi-bin/browse-edgar?CIK={}&owner=exclude&action=getcompany&Find=Search".format(symbol)

driver.get(url)

# %%
content_div = driver.find_element_by_id("contentDiv")



table = content_div.find_element_by_class_name("tableFile2")
table.get_attribute('innerHTML')

rows = table.find_elements_by_xpath("tbody/*")
print(len(rows))

for i in range(1, len(rows)):
    row = rows[i]
    cols = row.find_elements_by_xpath("*")
    assert len(cols) == 5
    if cols[0].get_attribute('innerHTML') == "10-Q":
        date = cols[3].get_attribute('innerHTML')
        print("{} 10-Q form  -   {}".format(i, date))
# Out:
# 41
# 1 10-Q form  -   2015-07-22
# 13 10-Q form  -   2015-04-28
# 27 10-Q form  -   2015-01-28

# %% [markdown]
# ### click next

# %%
butt_next = driver.find_elements_by_xpath("//input[@value='Next 40']")
if len(butt_next) > 0:
    butt_next[0].click()
else:
    print("last page..")
# Out:
# last page..
